# %%
import numpy as np
import os
from PIL import Image
import re

# %%
data_dir = 'F:\\Vikranth\\Masters\\8th\\209AS\\cifar\\cifar'

class_dict = {
    'airplane': 0,
    'automobile':1,
    'bird':2,
    'cat':3,
    'deer':4,
    'dog':5,
    'frog':6,
    'horse':7,
    'ship':8,
    'truck':9
}

# %%
def prepare_dataset(data_dir, folder_name):
    image_list = []
    labels = []
    train_dir = os.path.join(data_dir, folder_name)
    names = os.listdir(train_dir)
    for image in names:
        image_list.append(imageio.imread(os.path.join(train_dir, image)))
        label = re.split('[._]', image)
        labels.append(class_dict[label[1]])
        print(image)
    X = np.stack(image_list, axis=0)
    y = np.array(labels)
    return X,y

# %%
# Out:
# 50000

# %%
X_train, y_train = prepare_dataset(data_dir, 'train')
# Out:
# 0_frog.png
# 10000_automobile.png
# 10001_frog.png
# 10002_frog.png
# 10003_ship.png
# 10004_ship.png
# 10005_cat.png
# 10006_deer.png
# 10007_frog.png
# 10008_airplane.png
# 10009_frog.png
# 1000_truck.png
# 10010_airplane.png
# 10011_cat.png
# 10012_frog.png
# 10013_frog.png
# 10014_dog.png
# 10015_deer.png
# 10016_ship.png
# 10017_cat.png
# 10018_bird.png
# 10019_frog.png
# 1001_deer.png
# 10020_airplane.png
# 10021_cat.png
# 10022_automobile.png
# 10023_deer.png
# 10024_airplane.png
# 10025_frog.png
# 10026_frog.png
# 10027_bird.png
# 10028_horse.png
# 10029_frog.png
# 1002_cat.png
# 10030_truck.png
# 10031_airplane.png
# 10032_deer.png
# 10033_dog.png
# 10034_horse.png
# 10035_automobile.png
# 10036_frog.png
# 10037_horse.png
# 10038_truck.png
# 10039_automobile.png
# 1003_bird.png
# 10040_horse.png
# 10041_horse.png
# 10042_ship.png
# 10043_airplane.png
# 10044_cat.png
# 10045_horse.png
# 10046_deer.png
# 10047_horse.png
# 10048_cat.png
# 10049_automobile.png
# 1004_deer.png
# 10050_airplane.png
# 10051_deer.png
# 10052_frog.png
# 10053_frog.png
# 10054_automobile.png
# 10055_deer.png
# 10056_truck.png
# 10057_bird.png
# 10058_frog.png
# 10059_deer.png
# 1005_deer.png
# 10060_dog.png
# 10061_airplane.png
# 10062_deer.png
# 10063_frog.png
# 10064_airplane.png
# 10065_ship.png
# 10066_cat.png
# 10067_deer.png
# 10068_ship.png
# 10069_ship.png
# 1006_automobile.png
# 10070_cat.png
# 10071_truck.png
# 10072_dog.png
# 10073_horse.png
# 10074_automobile.png
# 10075_truck.png
# 10076_deer.png
# 10077_horse.png
# 10078_truck.png
# 10079_automobile.png
# 1007_deer.png
# 10080_truck.png
# 10081_horse.png
# 10082_dog.png
# 10083_bird.png
# 10084_horse.png
# 10085_cat.png
# 10086_deer.png
# 10087_ship.png
# 10088_ship.png
# 10089_bird.png
# 1008_bird.png
# 10090_automobile.png
# 10091_dog.png
# 10092_truck.png
# 10093_bird.png
# 10094_horse.png
# 10095_ship.png
# 10096_ship.png
# 10097_frog.png
# 10098_ship.png
# 10099_ship.png
# 1009_bird.png
# 100_ship.png
# 10237_deer.png
# 10238_frog.png
# 10239_deer.png
# 1023_frog.png
# 10240_bird.png
# 10241_bird.png
# 10242_dog.png
# 10243_airplane.png
# 10244_cat.png
# 10245_ship.png
# 10246_truck.png
# 10247_deer.png
# 10248_automobile.png
# 10249_automobile.png
# 1024_bird.png
# 10250_deer.png
# 10251_automobile.png
# 10252_truck.png
# 10253_frog.png
# 10254_cat.png
# 10255_cat.png
# 10256_frog.png
# 10257_truck.png
# 10258_dog.png
# 10259_horse.png
# 1025_cat.png
# 10260_frog.png
# 10261_truck.png
# 10262_deer.png
# 10263_bird.png
# 10264_deer.png
# 10265_airplane.png
# 10266_airplane.png
# 10267_airplane.png
# 10268_ship.png
# 10269_horse.png
# 1026_truck.png
# 10270_dog.png
# 10271_automobile.png
# 10272_ship.png
# 10273_frog.png
# 10274_horse.png
# 10275_airplane.png
# 10276_automobile.png
# 10277_horse.png
# 10278_horse.png
# 10279_ship.png
# 1027_frog.png
# 10280_bird.png
# 10281_horse.png
# 10282_deer.png
# 10283_ship.png
# 10284_ship.png
# 10285_truck.png
# 10286_ship.png
# 10287_truck.png
# 10288_ship.png
# 10289_bird.png
# 1028_truck.png
# 10290_ship.png
# 10291_truck.png
# 10292_automobile.png
# 10293_cat.png
# 10294_dog.png
# 10295_horse.png
# 10296_deer.png
# 10297_airplane.png
# 10298_automobile.png
# 10299_deer.png
# 1029_automobile.png
# 102_truck.png
# 10300_deer.png
# 10301_airplane.png
# 10302_ship.png
# 10303_deer.png
# 10304_cat.png
# 10305_horse.png
# 10306_truck.png
# 10307_horse.png
# 10308_horse.png
# 10309_truck.png
# 1030_cat.png
# 10310_cat.png
# 10311_frog.png
# 10312_truck.png
# 10313_ship.png
# 10314_automobile.png
# 10315_dog.png
# 10316_truck.png
# 10317_ship.png
# 10318_dog.png
# 10319_dog.png
# 1031_frog.png
# 10320_cat.png
# 10321_cat.png
# 10322_cat.png
# 10323_airplane.png
# 10324_dog.png
# 10325_automobile.png
# 10326_airplane.png
# 10327_frog.png
# 10328_horse.png
# 10329_cat.png
# 1032_ship.png
# 10330_airplane.png
# 10331_truck.png
# 10332_airplane.png
# 10333_horse.png
# 10334_airplane.png
# 10335_deer.png
# 10336_ship.png
# 10337_ship.png
# 10338_airplane.png
# 10339_horse.png
# 1033_dog.png
# 10340_airplane.png
# 10341_cat.png
# 10342_truck.png
# 10343_airplane.png
# 10344_ship.png
# 10345_frog.png
# 10346_ship.png
# 10347_horse.png
# 10348_horse.png
# 10349_frog.png
# 1034_truck.png
# 10350_deer.png
# 10351_truck.png
# 10352_automobile.png
# 10353_airplane.png
# 10354_ship.png
# 10355_airplane.png
# 10356_frog.png
# 10357_frog.png
# 10358_horse.png
# 10359_automobile.png
# 1035_frog.png
# 10360_bird.png
# 10361_ship.png
# 10362_automobile.png
# 10363_automobile.png
# 10364_frog.png
# 10365_airplane.png
# 10366_dog.png
# 10367_deer.png
# 10368_horse.png
# 10369_ship.png
# 1036_ship.png
# 10370_automobile.png
# 10371_horse.png
# 10372_deer.png
# 10373_truck.png
# 10374_frog.png
# 10375_truck.png
# 10376_ship.png
# 10377_automobile.png
# 10378_bird.png
# 10379_frog.png
# 1037_automobile.png
# 10380_automobile.png
# 10381_ship.png
# 10382_dog.png
# 10383_cat.png
# 10384_horse.png
# 10385_deer.png
# 10386_horse.png
# 10387_automobile.png
# 10388_truck.png
# 10389_bird.png
# 1038_frog.png
# 10390_truck.png
# 10391_bird.png
# 10392_deer.png
# 10393_automobile.png
# 10394_airplane.png
# 10395_ship.png
# 10396_bird.png
# 10397_dog.png
# 10398_bird.png
# 10399_airplane.png
# 1039_airplane.png
# 103_frog.png
# 10400_frog.png
# 10401_airplane.png
# 10402_ship.png
# 10403_automobile.png
# 10404_deer.png
# 10405_truck.png
# 10406_bird.png
# 10407_dog.png
# 10408_ship.png
# 10409_bird.png
# 1040_bird.png
# 10410_dog.png
# 10411_ship.png
# 10412_bird.png
# 10413_dog.png
# 10414_cat.png
# 10415_deer.png
# 10416_ship.png
# 10417_bird.png
# 10418_cat.png
# 10419_deer.png
# 1041_cat.png
# 10420_automobile.png
# 10421_truck.png
# 10422_horse.png
# 10423_dog.png
# 10424_dog.png
# 10425_airplane.png
# 10426_deer.png
# 10427_cat.png
# 10428_bird.png
# 10429_dog.png
# 1042_horse.png
# 10430_cat.png
# 10431_frog.png
# 10432_dog.png
# 10433_bird.png
# 10434_ship.png
# 10435_horse.png
# 10436_bird.png
# 10437_ship.png
# 10438_bird.png
# 10439_cat.png
# 1043_truck.png
# 10440_bird.png
# 10441_cat.png
# 10442_ship.png
# 10443_ship.png
# 10444_frog.png
# 10445_ship.png
# 10446_automobile.png
# 10447_deer.png
# 10448_truck.png
# 10449_horse.png
# 1044_airplane.png
# 10450_automobile.png
# 10451_deer.png
# 10452_cat.png
# 10453_automobile.png
# 10454_cat.png
# 10455_airplane.png
# 10456_ship.png
# 10457_bird.png
# 10458_automobile.png
# 10459_horse.png
# 1045_truck.png
# 10460_frog.png
# 10461_bird.png
# 10462_cat.png
# 10463_cat.png
# 10464_cat.png
# 10465_horse.png
# 10466_horse.png
# 10467_truck.png
# 10468_cat.png
# 10469_bird.png
# 1046_horse.png
# 10470_airplane.png
# 10471_dog.png
# 10472_deer.png
# 10473_truck.png
# 10474_bird.png
# 10475_ship.png
# 10476_automobile.png
# 10477_deer.png
# 10478_deer.png
# 10479_automobile.png
# 1047_frog.png
# 10480_bird.png
# 10481_horse.png
# 10482_dog.png
# 10483_ship.png
# 10484_dog.png
# 10485_deer.png
# 10486_airplane.png
# 10487_airplane.png
# 10488_cat.png
# 10489_deer.png
# 1048_cat.png
# 10490_horse.png
# 10491_automobile.png
# 10492_cat.png
# 10493_airplane.png
# 10494_truck.png
# 10495_automobile.png
# 10496_horse.png
# 10497_truck.png
# 10498_bird.png
# 10499_airplane.png
# 1049_truck.png
# 104_frog.png
# 10500_deer.png
# 10501_cat.png
# 10502_horse.png
# 10503_dog.png
# 10504_truck.png
# 10505_bird.png
# 10506_cat.png
# 10507_horse.png
# 10508_cat.png
# 10509_dog.png
# 1050_bird.png
# 10510_frog.png
# 10511_ship.png
# 10512_bird.png
# 10513_airplane.png
# 10514_dog.png
# 10515_dog.png
# 10516_airplane.png
# 10517_frog.png
# 10518_cat.png
# 10519_deer.png
# 1051_frog.png
# 10520_truck.png
# 10521_dog.png
# 10522_automobile.png
# 10523_truck.png
# 10524_ship.png
# 10525_deer.png
# 10526_airplane.png
# 10527_cat.png
# 10528_horse.png
# 10529_horse.png
# 1052_automobile.png
# 10530_ship.png
# 10531_automobile.png
# 10532_frog.png
# 10533_truck.png
# 10534_cat.png
# 10535_automobile.png
# 10536_deer.png
# 10537_ship.png
# 10538_horse.png
# 10539_deer.png
# 1053_frog.png
# 10540_horse.png
# 10541_dog.png
# 10542_dog.png
# 10543_ship.png
# 10544_automobile.png
# 10545_airplane.png
# 10546_horse.png
# 10547_horse.png
# 10548_airplane.png
# 10549_dog.png
# 1054_horse.png
# 10550_frog.png
# 10551_frog.png
# 10552_horse.png
# 10553_airplane.png
# 10554_frog.png
# 10555_dog.png
# 10556_dog.png
# 10557_cat.png
# 10558_cat.png
# 10559_truck.png
# 1055_cat.png
# 10560_horse.png
# 10561_deer.png
# 10562_horse.png
# 10563_frog.png
# 10564_automobile.png
# 10565_cat.png
# 10566_dog.png
# 10567_bird.png
# 10568_automobile.png
# 10569_automobile.png
# 1056_ship.png
# 10570_deer.png
# 10571_automobile.png
# 10572_ship.png
# 10573_horse.png
# 10574_airplane.png
# 10575_cat.png
# 10576_automobile.png
# 10577_airplane.png
# 10578_airplane.png
# 10579_frog.png
# 1057_cat.png
# 10580_horse.png
# 10581_truck.png
# 10582_bird.png
# 10583_horse.png
# 10584_horse.png
# 10585_ship.png
# 10586_dog.png
# 10587_cat.png
# 10588_bird.png
# 10589_airplane.png
# 1058_ship.png
# 10590_truck.png
# 10591_bird.png
# 10592_deer.png
# 10593_deer.png
# 10594_bird.png
# 10595_cat.png
# 10596_frog.png
# 10597_dog.png
# 10598_horse.png
# 10599_dog.png
# 1059_cat.png
# 105_automobile.png
# 10600_frog.png
# 10601_airplane.png
# 10602_horse.png
# 10603_dog.png
# 10604_deer.png
# 10605_deer.png
# 10606_ship.png
# 10607_airplane.png
# 10608_bird.png
# 10609_deer.png
# 1060_ship.png
# 10610_ship.png
# 10611_cat.png
# 10612_bird.png
# 10613_ship.png
# 10614_automobile.png
# 10615_deer.png
# 10616_bird.png
# 10617_airplane.png
# 10618_cat.png
# 10619_cat.png
# 1061_dog.png
# 10620_ship.png
# 10621_horse.png
# 10622_truck.png
# 10623_horse.png
# 10624_bird.png
# 10625_ship.png
# 10626_truck.png
# 10627_automobile.png
# 10628_bird.png
# 10629_deer.png
# 1062_truck.png
# 10630_automobile.png
# 10631_frog.png
# 10632_dog.png
# 10633_deer.png
# 10634_cat.png
# 10635_frog.png
# 10636_frog.png
# 10637_airplane.png
# 10638_ship.png
# 10639_ship.png
# 1063_frog.png
# 10640_deer.png
# 10641_deer.png
# 10642_automobile.png
# 10643_horse.png
# 10644_automobile.png
# 10645_ship.png
# 10646_ship.png
# 10647_frog.png
# 10648_automobile.png
# 10649_frog.png
# 1064_automobile.png
# 10650_airplane.png
# 10651_bird.png
# 10652_automobile.png
# 10653_cat.png
# 10654_deer.png
# 10655_automobile.png
# 10656_airplane.png
# 10657_dog.png
# 10658_truck.png
# 10659_truck.png
# 1065_bird.png
# 10660_bird.png
# 10661_deer.png
# 10662_truck.png
# 10663_ship.png
# 10664_ship.png
# 10665_frog.png
# 10666_horse.png
# 10667_airplane.png
# 10668_dog.png
# 10669_dog.png
# 1066_dog.png
# 10670_dog.png
# 10671_bird.png
# 10672_horse.png
# 10673_ship.png
# 10674_airplane.png
# 10675_airplane.png
# 10676_frog.png
# 10677_ship.png
# 10678_automobile.png
# 10679_automobile.png
# 1067_bird.png
# 10680_ship.png
# 10681_airplane.png
# 10682_ship.png
# 10683_bird.png
# 10684_horse.png
# 10685_horse.png
# 10686_airplane.png
# 10687_horse.png
# 10688_ship.png
# 10689_airplane.png
# 1068_automobile.png
# 10690_airplane.png
# 10691_dog.png
# 10692_dog.png
# 10693_automobile.png
# 10694_deer.png
# 10695_horse.png
# 10696_dog.png
# 10697_deer.png
# 10698_truck.png
# 10699_deer.png
# 1069_deer.png
# 106_ship.png
# 10700_bird.png
# 10701_deer.png
# 10702_ship.png
# 10703_dog.png
# 10704_frog.png
# 10705_cat.png
# 10706_deer.png
# 10707_deer.png
# 10708_ship.png
# 10709_dog.png
# 1070_cat.png
# 10710_dog.png
# 10711_automobile.png
# 10712_horse.png
# 10713_airplane.png
# 10714_automobile.png
# 10715_dog.png
# 10716_airplane.png
# 10717_truck.png
# 10718_frog.png
# 10719_deer.png
# 1071_horse.png
# 10720_deer.png
# 10721_ship.png
# 10722_cat.png
# 10723_truck.png
# 10724_dog.png
# 10725_bird.png
# 10726_dog.png
# 10727_horse.png
# 10728_deer.png
# 10729_airplane.png
# 1072_dog.png
# 10730_horse.png
# 10731_cat.png
# 10732_airplane.png
# 10733_frog.png
# 10734_horse.png
# 10735_horse.png
# 10736_deer.png
# 10737_dog.png
# 10738_frog.png
# 10739_dog.png
# 1073_truck.png
# 10740_dog.png
# 10741_airplane.png
# 10742_bird.png
# 10743_truck.png
# 10744_dog.png
# 10745_cat.png
# 10746_cat.png
# 10747_automobile.png
# 10748_automobile.png
# 10749_cat.png
# 1074_cat.png
# 10750_bird.png
# 10751_truck.png
# 10752_cat.png
# 10753_cat.png
# 10754_horse.png
# 10755_automobile.png
# 10756_bird.png
# 10757_frog.png
# 10758_dog.png
# 10759_dog.png
# 1075_truck.png
# 10760_dog.png
# 10761_airplane.png
# 10762_truck.png
# 10763_ship.png
# 10764_airplane.png
# 10765_deer.png
# 10766_deer.png
# 10767_bird.png
# 10768_dog.png
# 10769_truck.png
# 1076_cat.png
# 10770_cat.png
# 10771_automobile.png
# 10772_horse.png
# 10773_ship.png
# 10774_frog.png
# 10775_ship.png
# 10776_airplane.png
# 10777_airplane.png
# 10778_horse.png
# 10779_horse.png
# 1077_bird.png
# 10780_dog.png
# 10781_truck.png
# 10782_airplane.png
# 10783_frog.png
# 10784_cat.png
# 10785_ship.png
# 10786_frog.png
# 10787_airplane.png
# 10788_cat.png
# 10789_horse.png
# 1078_truck.png
# 10790_automobile.png
# 10791_truck.png
# 10792_frog.png
# 10793_truck.png
# 10794_frog.png
# 10795_automobile.png
# 10796_airplane.png
# 10797_automobile.png
# 10798_airplane.png
# 10799_truck.png
# 1079_automobile.png
# 107_dog.png
# 10800_dog.png
# 10801_bird.png
# 10802_bird.png
# 10803_dog.png
# 10804_airplane.png
# 10805_ship.png
# 10806_truck.png
# 10807_bird.png
# 10808_deer.png
# 10809_cat.png
# 1080_ship.png
# 10810_ship.png
# 10811_airplane.png
# 10812_airplane.png
# 10813_horse.png
# 10814_cat.png
# 10815_frog.png
# 10816_horse.png
# 10817_ship.png
# 10818_horse.png
# 10819_automobile.png
# 1081_dog.png
# 10820_dog.png
# 10821_frog.png
# 10822_ship.png
# 10823_horse.png
# 10824_automobile.png
# 10825_cat.png
# 10826_automobile.png
# 10827_truck.png
# 10828_frog.png
# 10829_truck.png
# 1082_truck.png
# 10830_truck.png
# 10831_dog.png
# 10832_automobile.png
# 10833_bird.png
# 10834_deer.png
# 10835_dog.png
# 10836_ship.png
# 10837_frog.png
# 10838_deer.png
# 10839_automobile.png
# 1083_horse.png
# 10840_ship.png
# 10841_frog.png
# 10842_bird.png
# 10843_cat.png
# 10844_dog.png
# 10845_truck.png
# 10846_automobile.png
# 10847_airplane.png
# 10848_ship.png
# 10849_deer.png
# 1084_bird.png
# 10850_truck.png
# 10851_deer.png
# 10852_horse.png
# 10853_truck.png
# 10854_cat.png
# 10855_airplane.png
# 10856_ship.png
# 10857_cat.png
# 10858_horse.png
# 10859_truck.png
# 1085_frog.png
# 10860_bird.png
# 10861_deer.png
# 10862_dog.png
# 10863_dog.png
# 10864_ship.png
# 10865_deer.png
# 10866_bird.png
# 10867_airplane.png
# 10868_automobile.png
# 10869_cat.png
# 1086_airplane.png
# 10870_cat.png
# 10871_horse.png
# 10872_airplane.png
# 10873_horse.png
# 10874_horse.png
# 10875_deer.png
# 10876_ship.png
# 10877_deer.png
# 10878_dog.png
# 10879_horse.png
# 1087_ship.png
# 10880_dog.png
# 10881_truck.png
# 10882_automobile.png
# 10883_cat.png
# 10884_horse.png
# 10885_bird.png
# 10886_horse.png
# 10887_horse.png
# 10888_deer.png
# 10889_frog.png
# 1088_dog.png
# 10890_deer.png
# 10891_horse.png
# 10892_horse.png
# 10893_airplane.png
# 10894_truck.png
# 10895_automobile.png
# 10896_airplane.png
# 10897_dog.png
# 10898_bird.png
# 10899_truck.png
# 1089_horse.png
# 108_bird.png
# 10900_deer.png
# 10901_bird.png
# 10902_automobile.png
# 10903_ship.png
# 10904_deer.png
# 10905_horse.png
# 10906_ship.png
# 10907_dog.png
# 10908_frog.png
# 10909_frog.png
# 1090_automobile.png
# 10910_automobile.png
# 10911_airplane.png
# 10912_automobile.png
# 10913_deer.png
# 10914_dog.png
# 10915_truck.png
# 10916_horse.png
# 10917_ship.png
# 10918_cat.png
# 10919_ship.png
# 1091_dog.png
# 10920_frog.png
# 10921_dog.png
# 10922_frog.png
# 10923_ship.png
# 10924_dog.png
# 10925_deer.png
# 10926_bird.png
# 10927_horse.png
# 10928_ship.png
# 10929_cat.png
# 1092_ship.png
# 10930_truck.png
# 10931_cat.png
# 10932_horse.png
# 10933_bird.png
# 10934_truck.png
# 10935_bird.png
# 10936_frog.png
# 10937_cat.png
# 10938_frog.png
# 10939_frog.png
# 1093_dog.png
# 10940_bird.png
# 10941_truck.png
# 10942_cat.png
# 10943_truck.png
# 10944_bird.png
# 10945_dog.png
# 10946_frog.png
# 10947_deer.png
# 10948_cat.png
# 10949_cat.png
# 1094_horse.png
# 10950_deer.png
# 10951_deer.png
# 10952_airplane.png
# 10953_automobile.png
# 10954_airplane.png
# 10955_airplane.png
# 10956_ship.png
# 10957_horse.png
# 10958_cat.png
# 10959_bird.png
# 1095_automobile.png
# 10960_cat.png
# 10961_frog.png
# 10962_ship.png
# 10963_automobile.png
# 10964_automobile.png
# 10965_ship.png
# 10966_deer.png
# 10967_cat.png
# 10968_bird.png
# 10969_automobile.png
# 1096_dog.png
# 10970_deer.png
# 10971_dog.png
# 10972_truck.png
# 10973_deer.png
# 10974_ship.png
# 10975_ship.png
# 10976_bird.png
# 10977_automobile.png
# 10978_dog.png
# 10979_deer.png
# 1097_airplane.png
# 10980_ship.png
# 10981_cat.png
# 10982_deer.png
# 10983_truck.png
# 10984_frog.png
# 10985_frog.png
# 10986_ship.png
# 10987_airplane.png
# 10988_horse.png
# 10989_airplane.png
# 1098_cat.png
# 10990_airplane.png
# 10991_bird.png
# 10992_automobile.png
# 10993_cat.png
# 10994_horse.png
# 10995_dog.png
# 10996_truck.png
# 10997_ship.png
# 10998_horse.png
# 10999_cat.png
# 1099_truck.png
# 109_truck.png
# 10_deer.png
# 11000_automobile.png
# 11001_ship.png
# 11002_airplane.png
# 11003_bird.png
# 11004_dog.png
# 11005_ship.png
# 11006_bird.png
# 11007_automobile.png
# 11008_airplane.png
# 11009_frog.png
# 1100_cat.png
# 11010_ship.png
# 11011_cat.png
# 11012_bird.png
# 11013_ship.png
# 11014_airplane.png
# 11015_bird.png
# 11016_dog.png
# 11017_bird.png
# 11018_airplane.png
# 11019_horse.png
# 1101_frog.png
# 11020_deer.png
# 11021_deer.png
# 11022_airplane.png
# 11023_airplane.png
# 11024_dog.png
# 11025_cat.png
# 11026_cat.png
# 11027_ship.png
# 11028_cat.png
# 11029_airplane.png
# 1102_truck.png
# 11030_bird.png
# 11031_airplane.png
# 11032_dog.png
# 11033_deer.png
# 11034_dog.png
# 11035_bird.png
# 11036_deer.png
# 11037_automobile.png
# 11038_frog.png
# 11039_horse.png
# 1103_automobile.png
# 11040_cat.png
# 11041_frog.png
# 11042_ship.png
# 11043_dog.png
# 11044_frog.png
# 11045_deer.png
# 11046_horse.png
# 11047_cat.png
# 11048_frog.png
# 11049_ship.png
# 1104_cat.png
# 11050_bird.png
# 11051_horse.png
# 11052_cat.png
# 11053_horse.png
# 11054_airplane.png
# 11055_cat.png
# 11056_airplane.png
# 11057_horse.png
# 11058_ship.png
# 11059_horse.png
# 1105_truck.png
# 11060_airplane.png
# 11061_dog.png
# 11062_dog.png
# 11063_ship.png
# 11064_deer.png
# 11065_horse.png
# 11066_frog.png
# 11067_cat.png
# 11068_horse.png
# 11069_ship.png
# 1106_ship.png
# 11070_frog.png
# 11071_dog.png
# 11072_dog.png
# 11073_airplane.png
# 11074_deer.png
# 11075_automobile.png
# 11076_airplane.png
# 11077_dog.png
# 11078_airplane.png
# 11079_cat.png
# 1107_bird.png
# 11080_airplane.png
# 11081_deer.png
# 11082_automobile.png
# 11083_dog.png
# 11084_bird.png
# 11085_truck.png
# 11086_ship.png
# 11087_bird.png
# 11088_horse.png
# 11089_bird.png
# 1108_bird.png
# 11090_frog.png
# 11091_ship.png
# 11092_deer.png
# 11093_frog.png
# 11094_dog.png
# 11095_ship.png
# 11096_truck.png
# 11097_dog.png
# 11098_frog.png
# 11099_bird.png
# 1109_cat.png
# 110_truck.png
# 11100_airplane.png
# 11101_frog.png
# 11102_horse.png
# 11103_cat.png
# 11104_truck.png
# 11105_cat.png
# 11106_bird.png
# 11107_airplane.png
# 11108_horse.png
# 11109_automobile.png
# 1110_bird.png
# 11110_frog.png
# 11111_truck.png
# 11112_dog.png
# 11113_frog.png
# 11114_airplane.png
# 11115_bird.png
# 11116_deer.png
# 11117_ship.png
# 11118_deer.png
# 11119_cat.png
# 1111_dog.png
# 11120_cat.png
# 11121_dog.png
# 11122_airplane.png
# 11123_bird.png
# 11124_frog.png
# 11125_deer.png
# 11126_truck.png
# 11127_truck.png
# 11128_truck.png
# 11129_deer.png
# 1112_truck.png
# 11130_automobile.png
# 11131_cat.png
# 11132_automobile.png
# 11133_automobile.png
# 11134_automobile.png
# 11135_frog.png
# 11136_horse.png
# 11137_bird.png
# 11138_deer.png
# 11139_truck.png
# 1113_horse.png
# 11140_truck.png
# 11141_ship.png
# 11142_dog.png
# 11143_dog.png
# 11144_frog.png
# 11145_dog.png
# 11146_horse.png
# 11147_frog.png
# 11148_ship.png
# 11149_ship.png
# 1114_truck.png
# 11150_frog.png
# 11151_airplane.png
# 11152_truck.png
# 11153_dog.png
# 11154_horse.png
# 11155_dog.png
# 11156_bird.png
# 11157_truck.png
# 11158_ship.png
# 11159_ship.png
# 1115_truck.png
# 11160_dog.png
# 11161_deer.png
# 11162_horse.png
# 11163_automobile.png
# 11164_dog.png
# 11165_dog.png
# 11166_dog.png
# 11167_horse.png
# 11168_bird.png
# 11169_airplane.png
# 1116_ship.png
# 11170_truck.png
# 11171_bird.png
# 11172_truck.png
# 11173_truck.png
# 11174_dog.png
# 11175_bird.png
# 11176_airplane.png
# 11177_ship.png
# 11178_airplane.png
# 11179_automobile.png
# 1117_truck.png
# 11180_ship.png
# 11181_frog.png
# 11182_frog.png
# 11183_cat.png
# 11184_truck.png
# 11185_dog.png
# 11186_dog.png
# 11187_bird.png
# 11188_cat.png
# 11189_dog.png
# 1118_horse.png
# 11190_deer.png
# 11191_frog.png
# 11192_cat.png
# 11193_bird.png
# 11194_bird.png
# 11195_cat.png
# 11196_automobile.png
# 11197_bird.png
# 11198_bird.png
# 11199_cat.png
# 1119_airplane.png
# 111_ship.png
# 11200_ship.png
# 11201_dog.png
# 11202_bird.png
# 11203_horse.png
# 11204_frog.png
# 11205_cat.png
# 11206_ship.png
# 11207_ship.png
# 11208_airplane.png
# 11209_deer.png
# 1120_cat.png
# 11210_truck.png
# 11211_cat.png
# 11212_frog.png
# 11213_truck.png
# 11214_horse.png
# 11215_frog.png
# 11216_airplane.png
# 11217_dog.png
# 11218_airplane.png
# 11219_frog.png
# 1121_cat.png
# 11220_bird.png
# 11221_bird.png
# 11222_cat.png
# 11223_automobile.png
# 11224_airplane.png
# 11225_truck.png
# 11226_deer.png
# 11227_truck.png
# 11228_horse.png
# 11229_airplane.png
# 1122_bird.png
# 11230_truck.png
# 11231_cat.png
# 11232_truck.png
# 11233_frog.png
# 11234_cat.png
# 11235_deer.png
# 11236_cat.png
# 11237_airplane.png
# 11238_airplane.png
# 11239_frog.png
# 1123_airplane.png
# 11240_airplane.png
# 11241_bird.png
# 11242_automobile.png
# 11243_automobile.png
# 11244_ship.png
# 11245_dog.png
# 11246_frog.png
# 11247_dog.png
# 11248_ship.png
# 11249_deer.png
# 1124_cat.png
# 11250_deer.png
# 11251_airplane.png
# 11252_bird.png
# 11253_ship.png
# 11254_deer.png
# 11255_airplane.png
# 11256_bird.png
# 11257_cat.png
# 11258_truck.png
# 11259_dog.png
# 1125_horse.png
# 11260_horse.png
# 11261_ship.png
# 11262_dog.png
# 11263_airplane.png
# 11264_automobile.png
# 11265_ship.png
# 11266_ship.png
# 11267_dog.png
# 11268_cat.png
# 11269_dog.png
# 1126_frog.png
# 11270_bird.png
# 11271_cat.png
# 11272_ship.png
# 11273_frog.png
# 11274_dog.png
# 11275_truck.png
# 11276_airplane.png
# 11277_ship.png
# 11278_horse.png
# 11279_deer.png
# 1127_cat.png
# 11280_airplane.png
# 11281_horse.png
# 11282_deer.png
# 11283_airplane.png
# 11284_horse.png
# 11285_dog.png
# 11286_bird.png
# 11287_frog.png
# 11288_bird.png
# 11289_horse.png
# 1128_cat.png
# 11290_frog.png
# 11291_cat.png
# 11292_truck.png
# 11293_cat.png
# 11294_cat.png
# 11295_bird.png
# 11296_truck.png
# 11297_airplane.png
# 11298_dog.png
# 11299_deer.png
# 1129_bird.png
# 112_automobile.png
# 11300_horse.png
# 11301_automobile.png
# 11302_airplane.png
# 11303_frog.png
# 11304_airplane.png
# 11305_airplane.png
# 11306_ship.png
# 11307_cat.png
# 11308_automobile.png
# 11309_ship.png
# 1130_airplane.png
# 11310_frog.png
# 11311_truck.png
# 11312_truck.png
# 11313_bird.png
# 11314_dog.png
# 11315_deer.png
# 11316_truck.png
# 11317_dog.png
# 11318_frog.png
# 11319_frog.png
# 1131_frog.png
# 11320_cat.png
# 11321_horse.png
# 11322_dog.png
# 11323_horse.png
# 11324_cat.png
# 11325_airplane.png
# 11326_bird.png
# 11327_ship.png
# 11328_dog.png
# 11329_horse.png
# 1132_frog.png
# 11330_dog.png
# 11331_frog.png
# 11332_truck.png
# 11333_cat.png
# 11334_horse.png
# 11335_bird.png
# 11336_automobile.png
# 11337_cat.png
# 11338_horse.png
# 11339_cat.png
# 1133_dog.png
# 11340_bird.png
# 11341_dog.png
# 11342_bird.png
# 11343_ship.png
# 11344_cat.png
# 11345_ship.png
# 11346_frog.png
# 11347_dog.png
# 11348_bird.png
# 11349_bird.png
# 1134_dog.png
# 11350_horse.png
# 11351_dog.png
# 11352_ship.png
# 11353_cat.png
# 11354_bird.png
# 11355_horse.png
# 11356_airplane.png
# 11357_cat.png
# 11358_frog.png
# 11359_cat.png
# 1135_horse.png
# 11360_truck.png
# 11361_automobile.png
# 11362_bird.png
# 11363_frog.png
# 11364_cat.png
# 11365_dog.png
# 11366_cat.png
# 11367_automobile.png
# 11368_ship.png
# 11369_frog.png
# 1136_dog.png
# 11370_cat.png
# 11371_frog.png
# 11372_airplane.png
# 11373_truck.png
# 11374_airplane.png
# 11375_dog.png
# 11376_dog.png
# 11377_horse.png
# 11378_ship.png
# 11379_cat.png
# 1137_truck.png
# 11380_bird.png
# 11381_frog.png
# 11382_bird.png
# 11383_truck.png
# 11384_deer.png
# 11385_bird.png
# 11386_cat.png
# 11387_cat.png
# 11388_truck.png
# 11389_cat.png
# 1138_ship.png
# 11390_horse.png
# 11391_horse.png
# 11392_frog.png
# 11393_horse.png
# 11394_frog.png
# 11395_automobile.png
# 11396_dog.png
# 11397_frog.png
# 11398_deer.png
# 11399_truck.png
# 1139_bird.png
# 113_horse.png
# 11400_airplane.png
# 11401_deer.png
# 11402_deer.png
# 11403_automobile.png
# 11404_frog.png
# 11405_dog.png
# 11406_frog.png
# 11407_automobile.png
# 11408_frog.png
# 11409_cat.png
# 1140_truck.png
# 11410_horse.png
# 11411_horse.png
# 11412_frog.png
# 11413_ship.png
# 11414_horse.png
# 11415_bird.png
# 11416_airplane.png
# 11417_horse.png
# 11418_automobile.png
# 11419_cat.png
# 1141_ship.png
# 11420_bird.png
# 11421_automobile.png
# 11422_truck.png
# 11423_deer.png
# 11424_airplane.png
# 11425_airplane.png
# 11426_horse.png
# 11427_automobile.png
# 11428_horse.png
# 11429_frog.png
# 1142_airplane.png
# 11430_truck.png
# 11431_airplane.png
# 11432_frog.png
# 11433_bird.png
# 11434_cat.png
# 11435_deer.png
# 11436_bird.png
# 11437_dog.png
# 11438_frog.png
# 11439_frog.png
# 1143_deer.png
# 11440_airplane.png
# 11441_dog.png
# 11442_dog.png
# 11443_bird.png
# 11444_automobile.png
# 11445_frog.png
# 11446_horse.png
# 11447_cat.png
# 11448_horse.png
# 11449_cat.png
# 1144_airplane.png
# 11450_dog.png
# 11451_airplane.png
# 11452_bird.png
# 11453_truck.png
# 11454_bird.png
# 11455_bird.png
# 11456_bird.png
# 11457_truck.png
# 11458_cat.png
# 11459_frog.png
# 11596_cat.png
# 11597_truck.png
# 11598_ship.png
# 11599_truck.png
# 1159_frog.png
# 115_airplane.png
# 11600_dog.png
# 11601_truck.png
# 11602_frog.png
# 11603_dog.png
# 11604_truck.png
# 11605_horse.png
# 11606_bird.png
# 11607_truck.png
# 11608_horse.png
# 11609_frog.png
# 1160_cat.png
# 11610_dog.png
# 11611_horse.png
# 11612_airplane.png
# 11613_ship.png
# 11614_automobile.png
# 11615_airplane.png
# 11616_ship.png
# 11617_cat.png
# 11618_airplane.png
# 11619_automobile.png
# 1161_frog.png
# 11620_truck.png
# 11621_horse.png
# 11622_dog.png
# 11623_cat.png
# 11624_dog.png
# 11625_cat.png
# 11626_deer.png
# 11627_ship.png
# 11628_cat.png
# 11629_bird.png
# 1162_ship.png
# 11630_bird.png
# 11631_automobile.png
# 11632_cat.png
# 11633_airplane.png
# 11634_frog.png
# 11635_deer.png
# 11636_dog.png
# 11637_dog.png
# 11638_frog.png
# 11639_cat.png
# 1163_bird.png
# 11640_automobile.png
# 11641_bird.png
# 11642_airplane.png
# 11643_airplane.png
# 11644_frog.png
# 11645_automobile.png
# 11646_automobile.png
# 11647_frog.png
# 11648_horse.png
# 11649_deer.png
# 1164_cat.png
# 11650_bird.png
# 11651_frog.png
# 11652_ship.png
# 11653_cat.png
# 11654_frog.png
# 11655_cat.png
# 11656_horse.png
# 11657_frog.png
# 11658_truck.png
# 11659_truck.png
# 1165_horse.png
# 11660_truck.png
# 11661_airplane.png
# 11662_dog.png
# 11663_automobile.png
# 11664_automobile.png
# 11665_ship.png
# 11666_bird.png
# 11667_ship.png
# 11668_cat.png
# 11669_horse.png
# 1166_airplane.png
# 11670_deer.png
# 11671_airplane.png
# 11672_frog.png
# 11673_ship.png
# 11674_ship.png
# 11675_frog.png
# 11676_ship.png
# 11677_truck.png
# 11678_truck.png
# 11679_automobile.png
# 1167_horse.png
# 11680_cat.png
# 11681_truck.png
# 11682_airplane.png
# 11683_automobile.png
# 11684_bird.png
# 11685_truck.png
# 11686_automobile.png
# 11687_frog.png
# 11688_truck.png
# 11689_airplane.png
# 1168_airplane.png
# 11690_frog.png
# 11691_airplane.png
# 11692_automobile.png
# 11693_ship.png
# 11694_dog.png
# 11695_automobile.png
# 11696_automobile.png
# 11697_horse.png
# 11698_automobile.png
# 11699_frog.png
# 1169_deer.png
# 116_airplane.png
# 11700_truck.png
# 11701_dog.png
# 11702_automobile.png
# 11703_truck.png
# 11704_horse.png
# 11705_bird.png
# 11706_ship.png
# 11707_automobile.png
# 11708_automobile.png
# 11709_airplane.png
# 1170_automobile.png
# 11710_bird.png
# 11711_frog.png
# 11712_dog.png
# 11713_bird.png
# 11714_cat.png
# 11715_truck.png
# 11716_automobile.png
# 11717_truck.png
# 11718_cat.png
# 11719_frog.png
# 1171_truck.png
# 11720_truck.png
# 11721_airplane.png
# 11722_dog.png
# 11723_dog.png
# 11724_cat.png
# 11725_dog.png
# 11726_frog.png
# 11727_cat.png
# 11728_frog.png
# 11729_frog.png
# 1172_dog.png
# 11730_bird.png
# 11731_bird.png
# 11732_airplane.png
# 11733_frog.png
# 11734_airplane.png
# 11735_dog.png
# 11736_cat.png
# 11737_dog.png
# 11738_cat.png
# 11739_cat.png
# 1173_horse.png
# 11740_dog.png
# 11741_horse.png
# 11742_horse.png
# 11743_cat.png
# 11744_automobile.png
# 11745_bird.png
# 11746_bird.png
# 11747_truck.png
# 11748_frog.png
# 11749_horse.png
# 1174_ship.png
# 11750_automobile.png
# 11751_frog.png
# 11752_cat.png
# 11753_dog.png
# 11754_frog.png
# 11755_truck.png
# 11756_frog.png
# 11757_deer.png
# 11758_cat.png
# 11759_deer.png
# 1175_frog.png
# 11760_cat.png
# 11761_horse.png
# 11762_airplane.png
# 11763_cat.png
# 11764_cat.png
# 11765_deer.png
# 11766_bird.png
# 11767_automobile.png
# 11768_airplane.png
# 11769_deer.png
# 1176_frog.png
# 11770_dog.png
# 11771_truck.png
# 11772_airplane.png
# 11773_truck.png
# 11774_truck.png
# 11775_airplane.png
# 11776_automobile.png
# 11777_truck.png
# 11778_horse.png
# 11779_bird.png
# 1177_ship.png
# 11780_frog.png
# 11781_horse.png
# 11782_automobile.png
# 11783_airplane.png
# 11784_frog.png
# 11785_deer.png
# 11786_truck.png
# 11787_automobile.png
# 11788_horse.png
# 11789_bird.png
# 1178_airplane.png
# 11790_dog.png
# 11791_automobile.png
# 11792_frog.png
# 11793_ship.png
# 11794_deer.png
# 11795_dog.png
# 11796_horse.png
# 11797_truck.png
# 11798_ship.png
# 11799_automobile.png
# 1179_horse.png
# 117_frog.png
# 11800_frog.png
# 11801_truck.png
# 11802_airplane.png
# 11803_truck.png
# 11804_automobile.png
# 11805_cat.png
# 11806_truck.png
# 11807_deer.png
# 11808_ship.png
# 11809_cat.png
# 1180_bird.png
# 11810_deer.png
# 11811_bird.png
# 11812_airplane.png
# 11813_bird.png
# 11814_truck.png
# 11815_bird.png
# 11816_bird.png
# 11817_automobile.png
# 11818_dog.png
# 11819_dog.png
# 1181_ship.png
# 11820_deer.png
# 11821_frog.png
# 11822_automobile.png
# 11823_frog.png
# 11824_automobile.png
# 11825_bird.png
# 11826_dog.png
# 11827_frog.png
# 11828_truck.png
# 11829_automobile.png
# 1182_deer.png
# 11830_ship.png
# 11831_automobile.png
# 11832_ship.png
# 11833_frog.png
# 11834_truck.png
# 11835_airplane.png
# 11836_cat.png
# 11837_horse.png
# 11838_airplane.png
# 11839_deer.png
# 1183_ship.png
# 11840_horse.png
# 11841_horse.png
# 11842_ship.png
# 11843_bird.png
# 11844_airplane.png
# 11845_deer.png
# 11846_horse.png
# 11847_dog.png
# 11848_horse.png
# 11849_airplane.png
# 1184_bird.png
# 11850_automobile.png
# 11851_frog.png
# 11852_dog.png
# 11853_dog.png
# 11854_dog.png
# 11855_cat.png
# 11856_truck.png
# 11857_automobile.png
# 11858_cat.png
# 11859_deer.png
# 1185_airplane.png
# 11860_deer.png
# 11861_dog.png
# 11862_deer.png
# 11863_ship.png
# 11864_cat.png
# 11865_truck.png
# 11866_ship.png
# 1267_bird.png
# 12680_truck.png
# 12681_cat.png
# 12682_dog.png
# 12683_horse.png
# 12684_frog.png
# 12685_automobile.png
# 12686_dog.png
# 12687_dog.png
# 12688_ship.png
# 12689_frog.png
# 1268_deer.png
# 12690_horse.png
# 12691_deer.png
# 12692_frog.png
# 12693_bird.png
# 12694_bird.png
# 12695_horse.png
# 12696_dog.png
# 12697_bird.png
# 12698_deer.png
# 12699_ship.png
# 1269_deer.png
# 126_automobile.png
# 12700_truck.png
# 12701_dog.png
# 12702_automobile.png
# 12703_bird.png
# 12704_airplane.png
# 12705_horse.png
# 12706_truck.png
# 12707_cat.png
# 12708_truck.png
# 12709_truck.png
# 1270_airplane.png
# 12710_bird.png
# 12711_bird.png
# 12712_truck.png
# 12713_horse.png
# 12714_horse.png
# 12715_truck.png
# 12716_dog.png
# 12717_deer.png
# 12718_truck.png
# 12719_automobile.png
# 1271_cat.png
# 12720_bird.png
# 12721_bird.png
# ...
# 14432_dog.png
# 14433_truck.png
# 14434_airplane.png
# 14435_bird.png
# 14436_truck.png
# 14437_dog.png
# 14438_ship.png
# 14439_bird.png
# 1443_bird.png
# 14440_deer.png
# 14441_airplane.png
# 14442_ship.png
# 14443_frog.png
# 14444_frog.png
# 14445_automobile.png
# 14446_horse.png
# 14447_deer.png
# 14448_automobile.png
# 14449_horse.png
# 1444_bird.png
# 14450_airplane.png
# 14451_automobile.png
# 14452_horse.png
# 14453_dog.png
# 14454_cat.png
# 14455_automobile.png
# 14456_airplane.png
# 14457_frog.png
# 14458_truck.png
# 14459_bird.png
# 1445_horse.png
# 14460_airplane.png
# 14461_automobile.png
# 14462_truck.png
# 14463_bird.png
# 14464_ship.png
# 14465_dog.png
# 14466_cat.png
# 14467_truck.png
# 14468_airplane.png
# 14469_deer.png
# 1446_automobile.png
# 14470_automobile.png
# 14471_truck.png
# 14472_bird.png
# 14473_bird.png
# 14474_deer.png
# 14475_truck.png
# 14476_frog.png
# 14477_dog.png
# 14478_bird.png
# 14479_airplane.png
# 1447_frog.png
# 14480_frog.png
# 14481_automobile.png
# 14482_airplane.png
# 14483_ship.png
# 14484_deer.png
# 14485_cat.png
# 14486_airplane.png
# 14487_airplane.png
# 14488_airplane.png
# 14489_horse.png
# 1448_automobile.png
# 14490_deer.png
# 14491_cat.png
# 14492_deer.png
# 14493_horse.png
# 14494_cat.png
# 14495_dog.png
# 14496_bird.png
# 14497_ship.png
# 14498_automobile.png
# 14499_airplane.png
# 1449_cat.png
# 144_bird.png
# 14500_bird.png
# 14501_automobile.png
# 14502_automobile.png
# 14503_horse.png
# 14504_dog.png
# 14505_frog.png
# 14506_truck.png
# 14507_automobile.png
# 14508_frog.png
# 14509_airplane.png
# 1450_deer.png
# 14510_truck.png
# 14511_cat.png
# 14512_automobile.png
# 14513_frog.png
# 14514_frog.png
# 14515_truck.png
# 14516_deer.png
# 14517_horse.png
# 14518_automobile.png
# 14519_automobile.png
# 1451_deer.png
# 14520_airplane.png
# 14521_deer.png
# 14522_dog.png
# 14523_truck.png
# 14524_automobile.png
# 14525_truck.png
# 14526_cat.png
# 14527_cat.png
# 14528_airplane.png
# 14529_ship.png
# 1452_ship.png
# 14530_dog.png
# 14531_horse.png
# 14532_deer.png
# 14533_dog.png
# 14534_airplane.png
# 14535_deer.png
# 14536_cat.png
# 14537_horse.png
# 14538_automobile.png
# 14539_ship.png
# 1453_frog.png
# 14540_horse.png
# 14541_truck.png
# 14542_ship.png
# 14543_cat.png
# 14544_frog.png
# 14545_truck.png
# 14546_automobile.png
# 14547_frog.png
# 14548_airplane.png
# 14549_automobile.png
# 1454_airplane.png
# 14550_airplane.png
# 14551_ship.png
# 14552_truck.png
# 14553_frog.png
# 14554_cat.png
# 14555_deer.png
# 14556_horse.png
# 14557_deer.png
# 14558_cat.png
# 14559_bird.png
# 1455_automobile.png
# 14560_deer.png
# 14561_horse.png
# 14562_truck.png
# 14563_truck.png
# 14564_truck.png
# 14565_ship.png
# 14566_deer.png
# 14567_airplane.png
# 14568_cat.png
# 14569_bird.png
# 1456_truck.png
# 14570_dog.png
# 14571_truck.png
# 14572_truck.png
# 14573_deer.png
# 14574_cat.png
# 14575_cat.png
# 14576_deer.png
# 14577_horse.png
# 14578_cat.png
# 14579_dog.png
# 1457_deer.png
# 14580_cat.png
# 14581_ship.png
# 14582_horse.png
# 14583_bird.png
# 14584_deer.png
# 14585_airplane.png
# 14586_truck.png
# 14587_ship.png
# 14588_bird.png
# 14589_horse.png
# 1458_bird.png
# 14590_cat.png
# 14591_airplane.png
# 14592_airplane.png
# 14593_automobile.png
# 14594_airplane.png
# 14595_bird.png
# 14596_horse.png
# 14597_airplane.png
# 14598_automobile.png
# 14599_truck.png
# 1459_horse.png
# 145_deer.png
# 14600_deer.png
# 14601_bird.png
# 14602_bird.png
# 14603_horse.png
# 14604_frog.png
# 14605_cat.png
# 14606_ship.png
# 14607_deer.png
# 14608_frog.png
# 14609_truck.png
# 1460_dog.png
# 14610_truck.png
# 14611_horse.png
# 14612_deer.png
# 14613_ship.png
# 14614_horse.png
# 14615_airplane.png
# 14616_truck.png
# 14617_truck.png
# 14618_deer.png
# 14619_bird.png
# 1461_cat.png
# 14620_bird.png
# 14621_frog.png
# 14622_frog.png
# 14623_cat.png
# 14624_ship.png
# 14625_frog.png
# 14626_truck.png
# 14627_dog.png
# 14628_frog.png
# 14629_frog.png
# 1462_truck.png
# 14630_horse.png
# 14631_frog.png
# 14632_dog.png
# 14633_horse.png
# 14634_deer.png
# 14635_deer.png
# 14636_horse.png
# 14637_ship.png
# 14638_frog.png
# 14639_frog.png
# 1463_airplane.png
# 14640_bird.png
# 14641_horse.png
# 14642_ship.png
# 14643_automobile.png
# 14644_deer.png
# 14645_deer.png
# 14646_bird.png
# 14647_cat.png
# 14648_ship.png
# 14649_deer.png
# 1464_automobile.png
# 14650_dog.png
# 14651_cat.png
# 14652_airplane.png
# 14653_horse.png
# 14654_airplane.png
# 14655_bird.png
# 14656_deer.png
# 14657_dog.png
# 14658_bird.png
# 14659_automobile.png
# 1465_truck.png
# 14660_frog.png
# 14661_truck.png
# 14662_automobile.png
# 14663_dog.png
# 14664_deer.png
# 14665_ship.png
# 14666_airplane.png
# 14667_deer.png
# 14668_automobile.png
# 14669_dog.png
# 1466_airplane.png
# 14670_deer.png
# 14671_horse.png
# 14672_bird.png
# 14673_dog.png
# 14674_cat.png
# 14675_bird.png
# 14676_automobile.png
# 14677_dog.png
# 14678_frog.png
# 14679_frog.png
# 1467_truck.png
# 14680_horse.png
# 14681_dog.png
# 14682_dog.png
# 14683_truck.png
# 14684_ship.png
# 14685_cat.png
# 14686_horse.png
# 14687_truck.png
# 14688_bird.png
# 14689_airplane.png
# 1468_ship.png
# 14690_deer.png
# 14691_dog.png
# 14692_horse.png
# 14693_ship.png
# 14694_frog.png
# 14695_truck.png
# 14696_dog.png
# 14697_bird.png
# 14698_airplane.png
# 14699_deer.png
# 1469_horse.png
# 146_truck.png
# 14700_dog.png
# 14701_frog.png
# 14702_cat.png
# 14703_cat.png
# 14704_deer.png
# 14705_truck.png
# 14706_cat.png
# 14707_dog.png
# 14708_airplane.png
# 14709_cat.png
# 1470_airplane.png
# 14710_ship.png
# 14711_ship.png
# 14712_airplane.png
# 14713_automobile.png
# 14714_ship.png
# 14715_bird.png
# 14716_automobile.png
# 14717_automobile.png
# 14718_ship.png
# 14719_frog.png
# 1471_deer.png
# 14720_bird.png
# 14721_automobile.png
# 14722_automobile.png
# 14723_truck.png
# 14724_dog.png
# 14725_horse.png
# 14726_deer.png
# 14727_airplane.png
# 14728_ship.png
# 14729_ship.png
# 1472_truck.png
# 14730_cat.png
# 14731_truck.png
# 14732_airplane.png
# 14733_horse.png
# 14734_dog.png
# 14735_cat.png
# 14736_ship.png
# 14737_deer.png
# 14738_horse.png
# 14739_bird.png
# 1473_airplane.png
# 14740_automobile.png
# 14741_horse.png
# 14742_horse.png
# 14743_truck.png
# 14744_deer.png
# 14745_horse.png
# 14746_frog.png
# 14747_deer.png
# 14748_dog.png
# 14749_frog.png
# 1474_dog.png
# 14750_dog.png
# 14751_cat.png
# 14752_bird.png
# 14753_ship.png
# 14754_airplane.png
# 14755_frog.png
# 14756_bird.png
# 14757_horse.png
# 14758_horse.png
# 14759_dog.png
# 1475_bird.png
# 14760_dog.png
# 14761_bird.png
# 14762_dog.png
# 14763_dog.png
# 14764_automobile.png
# 14765_truck.png
# 14766_ship.png
# 14767_ship.png
# 14768_bird.png
# 14769_bird.png
# 1476_automobile.png
# 14770_bird.png
# 14771_horse.png
# 14772_frog.png
# 14773_deer.png
# 14774_bird.png
# 14775_horse.png
# 14776_automobile.png
# 14777_deer.png
# 14778_airplane.png
# 14779_cat.png
# 1477_airplane.png
# 14780_horse.png
# 14781_deer.png
# 14782_airplane.png
# 14783_truck.png
# 14784_truck.png
# 14785_bird.png
# 14786_deer.png
# 14787_deer.png
# 14788_horse.png
# 14789_deer.png
# 1478_bird.png
# 14790_ship.png
# 14791_dog.png
# 14792_dog.png
# 14793_bird.png
# 14794_cat.png
# 14795_automobile.png
# 14796_airplane.png
# 14797_dog.png
# 14798_deer.png
# 14799_horse.png
# 1479_ship.png
# 147_truck.png
# 14800_cat.png
# 14801_horse.png
# 14802_dog.png
# 14803_truck.png
# 14804_ship.png
# 14805_automobile.png
# 14806_airplane.png
# 14807_airplane.png
# 14808_horse.png
# 14809_truck.png
# 1480_ship.png
# 14810_deer.png
# 14811_bird.png
# 14812_bird.png
# 14813_truck.png
# 14814_bird.png
# 14815_deer.png
# 14816_deer.png
# 14817_cat.png
# 14818_horse.png
# 14819_bird.png
# 1481_airplane.png
# 14820_cat.png
# 14821_ship.png
# 14822_horse.png
# 14823_ship.png
# 14824_frog.png
# 14825_truck.png
# 14826_ship.png
# 14827_deer.png
# 14828_frog.png
# 14829_bird.png
# 1482_dog.png
# 14830_frog.png
# 14831_ship.png
# 14832_ship.png
# 14833_frog.png
# 14834_bird.png
# 14835_bird.png
# 14836_automobile.png
# 14837_horse.png
# 14838_frog.png
# 14839_bird.png
# 1483_horse.png
# 14840_bird.png
# 14841_dog.png
# 14842_bird.png
# 14843_bird.png
# 14844_automobile.png
# 14845_frog.png
# 14846_ship.png
# 14847_truck.png
# 14848_airplane.png
# 14849_automobile.png
# 1484_frog.png
# 14850_dog.png
# 14851_automobile.png
# 14852_deer.png
# 14853_deer.png
# 14854_ship.png
# 14855_automobile.png
# 14856_airplane.png
# 14857_deer.png
# 14858_deer.png
# 14859_automobile.png
# 1485_frog.png
# 14860_bird.png
# 14861_cat.png
# 14862_horse.png
# 14863_horse.png
# 14864_frog.png
# 14865_horse.png
# 14866_ship.png
# 14867_airplane.png
# 14868_truck.png
# 14869_deer.png
# 1486_dog.png
# 14870_ship.png
# 14871_automobile.png
# 14872_ship.png
# 14873_frog.png
# 14874_automobile.png
# 14875_dog.png
# 14876_ship.png
# 14877_airplane.png
# 14878_automobile.png
# 14879_deer.png
# 1487_cat.png
# 14880_truck.png
# 14881_dog.png
# 14882_deer.png
# 14883_ship.png
# 14884_frog.png
# 14885_truck.png
# 14886_deer.png
# 14887_bird.png
# 14888_deer.png
# 14889_frog.png
# 1488_horse.png
# 14890_automobile.png
# 14891_ship.png
# 14892_truck.png
# 14893_deer.png
# 14894_frog.png
# 14895_truck.png
# 14896_dog.png
# 14897_horse.png
# 14898_airplane.png
# 14899_bird.png
# 1489_horse.png
# 148_dog.png
# 14900_automobile.png
# 14901_ship.png
# 14902_truck.png
# 14903_bird.png
# 14904_automobile.png
# 14905_deer.png
# 14906_frog.png
# 14907_deer.png
# 14908_dog.png
# 14909_airplane.png
# 1490_horse.png
# 14910_horse.png
# 14911_deer.png
# 14912_automobile.png
# 14913_truck.png
# 14914_deer.png
# 14915_bird.png
# 14916_frog.png
# 14917_truck.png
# 14918_bird.png
# 14919_cat.png
# 1491_deer.png
# 14920_cat.png
# 14921_deer.png
# 14922_ship.png
# 14923_deer.png
# 14924_cat.png
# 14925_deer.png
# 14926_bird.png
# 14927_automobile.png
# 14928_horse.png
# 14929_dog.png
# 1492_bird.png
# 14930_bird.png
# 14931_dog.png
# 14932_dog.png
# 14933_deer.png
# 14934_ship.png
# 14935_deer.png
# 14936_cat.png
# 14937_deer.png
# 14938_cat.png
# 14939_horse.png
# 1493_airplane.png
# 14940_frog.png
# 14941_cat.png
# 14942_cat.png
# 14943_deer.png
# 14944_horse.png
# 14945_airplane.png
# 14946_bird.png
# 14947_horse.png
# 14948_airplane.png
# 14949_airplane.png
# 1494_automobile.png
# 14950_frog.png
# 14951_frog.png
# 14952_dog.png
# 14953_truck.png
# 14954_truck.png
# 14955_horse.png
# 14956_deer.png
# 14957_deer.png
# 14958_airplane.png
# 14959_frog.png
# 1495_horse.png
# 14960_dog.png
# 14961_dog.png
# 14962_cat.png
# 14963_dog.png
# 14964_automobile.png
# 14965_dog.png
# 14966_automobile.png
# 14967_automobile.png
# 14968_cat.png
# 14969_ship.png
# 1496_cat.png
# 14970_truck.png
# 14971_ship.png
# 14972_cat.png
# 14973_frog.png
# 14974_deer.png
# 14975_dog.png
# 14976_horse.png
# 14977_horse.png
# 14978_automobile.png
# 14979_ship.png
# 1497_bird.png
# 14980_horse.png
# 14981_frog.png
# 14982_ship.png
# 14983_horse.png
# 14984_frog.png
# 14985_truck.png
# 14986_cat.png
# 14987_dog.png
# 14988_bird.png
# 14989_horse.png
# 1498_horse.png
# 14990_truck.png
# 14991_ship.png
# 14992_dog.png
# 14993_cat.png
# 14994_frog.png
# 14995_automobile.png
# 14996_deer.png
# 14997_deer.png
# 14998_truck.png
# 14999_frog.png
# 1499_cat.png
# 149_deer.png
# 14_truck.png
# 15000_airplane.png
# 15001_frog.png
# 15002_horse.png
# 15003_airplane.png
# 15004_deer.png
# 15005_truck.png
# 15006_dog.png
# 15007_ship.png
# 15008_airplane.png
# 15009_deer.png
# 1500_bird.png
# 15010_cat.png
# 15011_ship.png
# 15012_deer.png
# 15013_horse.png
# 15014_automobile.png
# 15015_ship.png
# 15016_cat.png
# 15017_dog.png
# 15018_deer.png
# 15019_dog.png
# 1501_bird.png
# 15020_horse.png
# 15021_deer.png
# 15022_ship.png
# 15023_frog.png
# 15024_deer.png
# 15025_ship.png
# 15026_frog.png
# 15027_truck.png
# 15028_frog.png
# 15029_dog.png
# 1502_automobile.png
# 15030_airplane.png
# 15031_truck.png
# 15032_dog.png
# 15033_truck.png
# 15034_bird.png
# 15035_frog.png
# 15036_deer.png
# 15037_horse.png
# 15038_frog.png
# 15039_frog.png
# 1503_dog.png
# 15040_frog.png
# 15041_frog.png
# 15042_automobile.png
# 15043_ship.png
# 15044_airplane.png
# 15045_horse.png
# 15046_ship.png
# 15047_horse.png
# 15048_frog.png
# 15049_ship.png
# 1504_truck.png
# 15050_frog.png
# 15051_automobile.png
# 15052_frog.png
# 15053_cat.png
# 15054_bird.png
# 15055_horse.png
# 15056_truck.png
# 15057_cat.png
# 15058_horse.png
# 15059_automobile.png
# 1505_truck.png
# 15060_frog.png
# 15061_automobile.png
# 15062_truck.png
# 15063_frog.png
# 15064_frog.png
# 15065_bird.png
# 15066_truck.png
# 15067_horse.png
# 15068_bird.png
# 15069_automobile.png
# 1506_ship.png
# 15070_horse.png
# 15071_frog.png
# 15072_horse.png
# 15073_horse.png
# 15074_dog.png
# 15075_frog.png
# 15076_frog.png
# 15077_airplane.png
# 15078_frog.png
# 15079_horse.png
# 1507_airplane.png
# 15080_cat.png
# 15081_horse.png
# 15082_truck.png
# 15083_cat.png
# 15084_frog.png
# 15085_truck.png
# 15086_airplane.png
# 15087_airplane.png
# 15088_bird.png
# 15089_dog.png
# 1508_ship.png
# 15090_truck.png
# 15091_bird.png
# 15092_ship.png
# 15093_frog.png
# 15094_bird.png
# 15095_deer.png
# 15096_truck.png
# 15097_airplane.png
# 15098_horse.png
# 15099_horse.png
# 1509_deer.png
# 150_cat.png
# 15100_automobile.png
# 15101_truck.png
# 15102_airplane.png
# 15103_dog.png
# 15104_truck.png
# 15105_deer.png
# 15106_cat.png
# 15107_frog.png
# 15108_cat.png
# 15109_bird.png
# 1510_cat.png
# 15110_frog.png
# 15111_ship.png
# 15112_deer.png
# 15113_airplane.png
# 15114_automobile.png
# 15115_airplane.png
# 15116_frog.png
# 15117_horse.png
# 15118_bird.png
# 15119_truck.png
# 1511_cat.png
# 15120_horse.png
# 15121_bird.png
# 15122_cat.png
# 15123_truck.png
# 15124_bird.png
# 15125_bird.png
# 15126_deer.png
# 15127_cat.png
# 15128_ship.png
# 15129_cat.png
# 1512_ship.png
# 15130_dog.png
# 15131_deer.png
# 15132_horse.png
# 15133_dog.png
# 15134_bird.png
# 15135_ship.png
# 15136_horse.png
# 15137_airplane.png
# 15138_cat.png
# 15139_bird.png
# 1513_dog.png
# 15140_deer.png
# 15141_truck.png
# 15142_truck.png
# 15143_deer.png
# 15144_bird.png
# 15145_cat.png
# 15146_bird.png
# 15147_airplane.png
# 15148_horse.png
# 15149_airplane.png
# 1514_airplane.png
# 15150_truck.png
# 15151_automobile.png
# 15152_deer.png
# 15153_airplane.png
# 15154_cat.png
# 15155_deer.png
# 15156_cat.png
# 15157_horse.png
# 15158_deer.png
# 15159_truck.png
# 1515_ship.png
# 15160_bird.png
# 15161_ship.png
# 15162_automobile.png
# 15163_frog.png
# 15164_ship.png
# 15165_frog.png
# 15166_dog.png
# 15167_horse.png
# 15168_deer.png
# 15169_cat.png
# 1516_deer.png
# 15170_deer.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-a435fea44aa4> in <module>()
# ----> 1 X_train, y_train = prepare_dataset(data_dir, 'train')
#
# <ipython-input-47-634ca472cb0f> in prepare_dataset(data_dir, folder_name)
#       5     names = os.listdir(train_dir)
#       6     for image in names:
# ----> 7         image_list.append(imageio.imread(os.path.join(train_dir, image)))
#       8         label = re.split('[._]', image)
#       9         labels.append(class_dict[label[1]])
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# --> 221     reader = read(uri, format, "i", **kwargs)
#     222     with reader:
#     223         return reader.get_data(0)
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\functions.py in get_reader(uri, format, mode, **kwargs)
#     134         format = formats[format]
#     135     else:
# --> 136         format = formats.search_read_format(request)
#     137     if format is None:
#     138         raise ValueError(
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\format.py in search_read_format(self, request)
#     685         # Select the first that can
#     686         for format in selected_formats:
# --> 687             if format.can_read(request):
#     688                 return format
#     689
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\format.py in can_read(self, request)
#     193         Get whether this format can read data from the specified uri.
#     194         """
# --> 195         return self._can_read(request)
#     196
#     197     def can_write(self, request):
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\plugins\pillow.py in _can_read(self, request)
#     102                 factory, accept = Image.OPEN[self.plugin_id]
#     103                 if accept:
# --> 104                     if request.firstbytes and accept(request.firstbytes):
#     105                         return True
#     106
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\request.py in firstbytes(self)
#     445         """
#     446         if self._firstbytes is None:
# --> 447             self._read_first_bytes()
#     448         return self._firstbytes
#     449
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\request.py in _read_first_bytes(self, N)
#     465                 i = None
#     466             # Read
# --> 467             self._firstbytes = read_n_bytes(f, N)
#     468             # Set back
#     469             try:
#
# c:\programdata\anaconda3\envs\tensorflow\lib\site-packages\imageio\core\request.py in read_n_bytes(f, N)
#     487     bb = binary_type()
#     488     while len(bb) < N:
# --> 489         extra_bytes = f.read(N - len(bb))
#     490         if not extra_bytes:
#     491             break
#
# KeyboardInterrupt:

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (14, 32, 32, 3)
# (14,)

# %%
X_train.dtype
# Out:
# dtype('uint8')

# %%
y_train
# Out:
# array([6, 4, 7, 7, 2, 9, 9, 4, 1, 1, 2, 7, 8, 3])

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
# Out:
# Using TensorFlow backend.

# %%
#z-score
mean = np.mean(X_train,axis=(0,1,2,3))
std = np.std(X_train,axis=(0,1,2,3))
X_train = (X_train-mean)/(std+1e-7)
X_test = (X_test-mean)/(std+1e-7)

# %%
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)
 
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
           activation='relu',
           input_shape=X_train.shape[1:],
           padding='same', name='Conv_1'))
model.add(BatchNormalization(name='Bn_1')) 
model.add(MaxPooling2D(pool_size=(2, 2), name='Max_pool_1'))  
model.add(Dropout(p, name='Drop_1'))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',padding='same',  name='Conv_2'))
model.add(BatchNormalization(name='Bn_2')) 
model.add(MaxPooling2D(pool_size=(2, 2), name='Max_pool_2'))  
model.add(Dropout(p, name='Drop_2'))
model.add(Flatten(name = 'Flatten_1'))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization(name='Bn_3')) 
model.add(Dropout(p, name='Drop_3'))
model.add(Dense(num_classes, activation='softmax', name='dense_out'))
model.summary()

# %%
def train_baseline_model(model, X_train, y_train, X_val, y_val, model_dir, n, batch_size=256, epochs=50):
    
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer='adam',
                  metrics=['accuracy'])

    # checkpoint
    chk_path = os.path.join(model_dir, 'best_baseline_{}_{}'.format(n, fr))
    checkpoint = ModelCheckpoint(chk_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    history = model.fit(X_train, y_train,
                batch_size=batch_size,
                epochs=epochs,
                verbose=1,
                shuffle=True,
                validation_data=(X_val, y_val),
                 callbacks=callbacks_list)
    
    #Saving the model
    model.save(os.path.join(model_dir, 'final_baseline_{}_{}_{}'.format(d_name, n, fr)))
    return model, history

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np
 
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)
 
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()
 
#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(x_train)
 
#training
batch_size = 64
 
opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=125,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])
#save to disk
model_json = model.to_json()
with open('model.json', 'w') as json_file:
    json_file.write(model_json)
model.save_weights('model.h5') 
 
#testing
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0])
